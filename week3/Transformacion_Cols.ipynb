# %% [markdown]
# ## Se transforman las columnas para mejorar la acuracy del modelo

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
Data = {
    "fuente": ["ana"],
    "asunto": ["hola"],
    "fecha": ["2024-06-01"],
    "campo": ["valor"],
    "spam": ["no"]
}
df = pd.DataFrame(Data) 
print(df)
# Out:
#   fuente asunto       fecha  campo spam
# 0    ana   hola  2024-06-01  valor   no
